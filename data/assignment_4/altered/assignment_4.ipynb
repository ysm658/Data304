# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('system_of_record_timestamps.csv')
df
# Out:
#     Record_ID     Primary_Timestamp Secondary_Timestamp Tertiary_Timestamp  \
# 0           1      01-10-2024 00:00                 NaN                NaN
# 1           2  2024-10-02T00:00:00Z                 NaN                NaN
# 2           3   10/03/2024 12:00 AM          1727913600                NaN
# 3           4   10/04/2024 12:00 AM          1728000000                NaN
# 4           5  2024-10-05T00:00:00Z                 NaN                NaN
# ..        ...                   ...                 ...                ...
# 88         89   12/28/2024 12:00 AM          1735344000         2024/28/12
# 89         90   12/29/2024 12:00 AM          1735430400                NaN
# 90         91  2024-12-30T00:00:00Z        -54 days ago                NaN
# 91         92  2024-12-31T00:00:00Z        -55 days ago         2024/31/12
# 92         93  2025-01-01T00:00:00Z          1735689600                NaN
#
#     Event_Count
# 0             1
# 1            12
# ...

# %%
plt.figure(figsize=(10, 5))
plt.plot(df["Primary_Timestamp"], df["Event_Count"], marker="o", linestyle="-", color="b")
plt.xlabel("Timestamp")
plt.ylabel("Event Count")
plt.title("Event Count Over Time")
plt.xticks(rotation=45)
plt.grid(True)

plt.show()

# %%
df.sort_values(by='Event_Count', ascending=False).head(12)
# Out:
#     Record_ID     Primary_Timestamp Secondary_Timestamp Tertiary_Timestamp  \
# 35         36  2024-11-05T00:00:00Z                 NaN                NaN
# 36         37  2024-11-06T00:00:00Z          0 days ago                NaN
# 34         35  2024-11-04T00:00:00Z          1730678400                NaN
# 37         38  2024-11-07T00:00:00Z          1730937600            2024-11
# 33         34  2024-11-03T00:00:00Z          3 days ago              Nov 3
# 38         39   11/08/2024 12:00 AM                 NaN                NaN
# 39         40  2024-11-09T00:00:00Z                 NaN                NaN
# 31         32   11/01/2024 12:00 AM                 NaN                NaN
# 30         31   10/31/2024 12:00 AM          6 days ago                NaN
# 41         42  2024-11-11T00:00:00Z          1731283200             Nov 11
# 29         30      30-10-2024 00:00          7 days ago                NaN
# ...

# %% [markdown]
# The web server likely crashed due to the high event count from indices 33-38. The graph shows a peak building around these records, but they are much higher than the other records. The server likely wasn't built to handle the volume of events in these records. Also, the different forms of dates in the dataset isn't ideal for doing analysis.
